# %%
import numpy as np 
import pandas as pd
import folium 
import math 
import os

# %%
df=pd.read_csv("距離矩陣0.csv",encoding="utf-8")

# %%
basemaps = {
    'Google Maps': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Maps',
        overlay = True,
        control = True
    ),
    'Google Satellite': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Google Terrain': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Terrain',
        overlay = True,
        control = True
    ),
    'Google Satellite Hybrid': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Esri Satellite': folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = True,
        control = True
    )
}

# %%
df
# Out:
#        Unnamed: 0  7-ELEVEN 豐安門市  全家便利商店 義興店  全家便利商店 復豐店  7-ELEVEN 信興門市  \
# 0   7-ELEVEN 豐安門市              0         350         100            500
# 1      全家便利商店 義興店            350           0         350            160
# 2      全家便利商店 復豐店            100         350           0            500
# 3   7-ELEVEN 信興門市            500         160         500              0
# 4   7-ELEVEN 信安門市            400         300         450            270
# 5      全家便利商店 興南店            400         100         400            180
# 6   萊爾富便利商店 大安仁醫店            250         650         260            750
# 7      全家便利商店 義安店            600         350         750            280
# 8      全家便利商店 仁慈店            400         750         400            700
# 9      全家便利商店 興仁店            500         750         400            850
# 10  臺北市立聯合醫院 仁愛院區            110         500         120            600
# 11        台北福華大飯店            240         500         240            600
#
# ...

# %%
m=folium.Map(location=[25.03605568443915,121.54515456049889],width=600,height=600,zoom_start=50)

# %%
df
# Out:
#        Unnamed: 0  7-ELEVEN 豐安門市  全家便利商店 義興店  全家便利商店 復豐店  7-ELEVEN 信興門市  \
# 0   7-ELEVEN 豐安門市              0         350         100            500
# 1      全家便利商店 義興店            350           0         350            160
# 2      全家便利商店 復豐店            100         350           0            500
# 3   7-ELEVEN 信興門市            500         160         500              0
# 4   7-ELEVEN 信安門市            400         300         450            270
# 5      全家便利商店 興南店            400         100         400            180
# 6   萊爾富便利商店 大安仁醫店            250         650         260            750
# 7      全家便利商店 義安店            600         350         750            280
# 8      全家便利商店 仁慈店            400         750         400            700
# 9      全家便利商店 興仁店            500         750         400            850
# 10  臺北市立聯合醫院 仁愛院區            110         500         120            600
# 11        台北福華大飯店            240         500         240            600
#
# ...

# %%
df.columns[1:-2]
# Out:
# Index(['7-ELEVEN 豐安門市', '全家便利商店 義興店', '全家便利商店 復豐店', '7-ELEVEN 信興門市',
#        '7-ELEVEN 信安門市', '全家便利商店 興南店', '萊爾富便利商店 大安仁醫店', '全家便利商店 義安店',
#        '全家便利商店 仁慈店', '全家便利商店 興仁店', '臺北市立聯合醫院 仁愛院區', '台北福華大飯店'],
#       dtype='object')

# %%
df["long"]
# Out:
# 0     25.036295
# 1     25.033739
# 2     25.036765
# 3     25.033251
# 4     25.034515
# 5     25.033060
# 6     25.037677
# 7     25.033219
# 8     25.037303
# 9     25.039338
# 10    25.037371
# 11    25.037679
# Name: long, dtype: float64

# %%
popup=df.columns[1:-2]
popup
# Out:
# Index(['7-ELEVEN 豐安門市', '全家便利商店 義興店', '全家便利商店 復豐店', '7-ELEVEN 信興門市',
#        '7-ELEVEN 信安門市', '全家便利商店 興南店', '萊爾富便利商店 大安仁醫店', '全家便利商店 義安店',
#        '全家便利商店 仁慈店', '全家便利商店 興仁店', '臺北市立聯合醫院 仁愛院區', '台北福華大飯店'],
#       dtype='object')

# %%
color="red"
for i in range(len(df)):
    if i ==10:
        color="green"
        folium.Marker([list(df.long)[i],list(df.lati)[i]], popup=popup[i], icon=folium.Icon(color=color,prefix='fa', icon="home")).add_to(m)
    elif i==11:
        color="blue"
        folium.Marker([list(df.long)[i],list(df.lati)[i]], popup=popup[i], icon=folium.Icon(color=color,prefix='fa', icon="star")).add_to(m)  
    else:
        folium.Marker([list(df.long)[i],list(df.lati)[i]], popup=popup[i], icon=folium.Icon(color=color )).add_to(m)

# %%
center_pos = [25.03737094, 121.545192]
m.add_child(folium.Circle(location=center_pos,
                             color='blue', # Circle 顏色
                             radius=550, # Circle 寬度
                             popup='Skytree', # 彈出視窗內容
                             fill=True, # 填滿中間區域
                             fill_opacity=0.5 # 設定透明度
                             ))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
basemaps['Google Maps'].add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
def  print_trace():
    m = folium.Map([25.03737094, 121.545192], zoom_start=15)  #中心区域的确定

    location = [[25.03771179,121.5429701,'台北福華大飯店'],
                [25.03678478,121.5439176,'全家便利商店 復豐店'],
                [25.03620226,121.5442555,'7-ELEVEN 豐安門市'],
                [25.03376778,121.5439279,'全家便利商店 義興店'],
                [25.03306046,121.543337,'全家便利商店 興南店'],
                [25.03332919,121.5447773,'7-ELEVEN 信興門市'],
                [25.03322848,121.5472987,'全家便利商店 義安店'],
                [25.0345347,121.5458881,'7-ELEVEN 信安門市'],
                [25.039339386367857,121.54392742853337,'全家便利商店 興仁店'],
                [25.03771612,121.5452025,'萊爾富便利商店 大安仁醫店'],
                [25.037303,121.5470167,'全家便利商店 仁慈店'],
                [25.03742926,121.545192,'臺北市立聯合醫院 仁愛院區']]  #输入坐标点（注意）folium包要求坐标形式以纬度在前，经度在后，经度在后


    #定义一个空列表将
    use_location=[]

    for i in range(len(location)):
        
        position_atitu = [location[i][0], location[i][1]]
        
        use_location.append([location[i][0], location[i][1]])
        
        if i < len(location) - 1:
            
            dx = location[i + 1][0] - location[i][0]  # dx
            
            dy = location[i + 1][1] - location[i][1]  # dy

            angle1 = math.atan2(dx, dy)

            angle2 = -int(angle1 * 180 / math.pi)

            mid_location = [location[i][0]+dx/2,location[i][1]+dy/2]


            #三角形图形指示方向，由于rotation的角度是顺时针旋转，
            color="red"
            for i in range(len(location)):
                if i ==10:
                    color="green"
                    folium.Marker([list(df.long)[i],list(df.lati)[i]], popup=popup[i], icon=folium.Icon(color=color,prefix='fa', icon="home")).add_to(m)
                elif i==11:
                    color="blue"
                    folium.Marker([list(df.long)[i],list(df.lati)[i]], popup=popup[i], icon=folium.Icon(color=color,prefix='fa', icon="star")).add_to(m)  
                else:
                    folium.Marker([list(df.long)[i],list(df.lati)[i]], popup=popup[i], icon=folium.Icon(color=color )).add_to(m)
            
            folium.RegularPolygonMarker(mid_location, fill_color='black', number_of_sides=3, radius=5,
                                    rotation=angle2).add_to(m)
               


    #polyline方法为将坐标用线段形式连接起来
    route = folium.PolyLine(
        
        use_location,    #将坐标点连接起来
        
        weight=5,  #线的大小为3
        
        color='blue',  #线的颜色为橙色
        
        opacity=0.5,    #线的透明度
    ).add_to(m)    #将这条线添加到刚才的区域m内
    basemaps['Google Maps'].add_to(m)
    m.save(os.path.join(r'C:/Users/yanti/Desktop/python爬蟲/city3.html'))
    
print_trace()

# %%
[11, 9, 6, 0, 2, 1, 5, 3, 7, 4, 8, 10]
